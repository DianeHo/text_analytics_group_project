# %%
import numpy as np
import pandas as pd

import nltk
import gensim
from tqdm import tqdm

import matplotlib.pyplot as plt

import os

import tba3102

# %%
# file_name = "cleaned-galaxy"
# file_name = "cleaned-apple_review"
file_name = "cleaned-samsung_vs_pixel"
df = pd.read_csv(f'../data/{file_name}.csv')
df['Cleaned_Comment'].replace(r'^(\s)+$', np.nan, regex=True, inplace=True)
df = df.dropna(subset=['Cleaned_Comment']).reset_index(drop=True)
df = df[df["Cleaned_Comment"].apply(lambda x: len(x) > 2)]
df.head()
# Out:
# C:\Users\tee_m\AppData\Local\Temp\ipykernel_11556\1961720941.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cleaned_Comment'].replace(r'^(\s)+$', np.nan, regex=True, inplace=True)
#   Comment ID                                       Comment Body       Author  Upvotes     Timestamp                                    Cleaned_Comment
# 0    m9aq3ty  Jeez this thread really opened up the fanboy w...   lunarmando      130  1.737913e+09  je thread really open fancy war I feel like fi...
# 1    m9ark0z  They said that indoor photography improved thi...      Deleted       36  1.737913e+09  say indoor photography improve generation say ...
# 2    m99b1im                                          [removed]      Deleted      190  1.737896e+09                                             remove
# 3    m99kwtr  Snapdragon 8 elite blows google’s tensor out o...   porygon766      147  1.737900e+09            snapdragon elite blow gorge tenor water
# 4    m99f0bd  Tensor chip, no UFS 4.0 but of course if it's ...  Teo_Yanchev       90  1.737898e+09  tenor chip course goose issue fix flagship pho...

# %%
# df_merge = pd.DataFrame()
# names = ["cleaned-galaxy", "cleaned-apple_review", "cleaned-samsung_vs_pixel"]
# for name in names:
#     curr = pd.read_csv(f'../data/{name}.csv')
#     curr['Cleaned_Comment'].replace(r'^(\s)+$', np.nan, regex=True, inplace=True)
#     curr = curr.dropna(subset=['Cleaned_Comment']).reset_index(drop=True)
#     curr = curr[curr["Cleaned_Comment"].apply(lambda x: len(x) > 2)]
#     df_merge = pd.concat([df_merge, curr], axis=0)
    
# file_name = "ALL"
# df_merge.reset_index(inplace=True, drop=True)
# df = df_merge

# %%
df.head()
# Out:
#   Comment ID                                       Comment Body       Author  Upvotes     Timestamp                                    Cleaned_Comment
# 0    m9aq3ty  Jeez this thread really opened up the fanboy w...   lunarmando      130  1.737913e+09  je thread really open fancy war I feel like fi...
# 1    m9ark0z  They said that indoor photography improved thi...      Deleted       36  1.737913e+09  say indoor photography improve generation say ...
# 2    m99b1im                                          [removed]      Deleted      190  1.737896e+09                                             remove
# 3    m99kwtr  Snapdragon 8 elite blows google’s tensor out o...   porygon766      147  1.737900e+09            snapdragon elite blow gorge tenor water
# 4    m99f0bd  Tensor chip, no UFS 4.0 but of course if it's ...  Teo_Yanchev       90  1.737898e+09  tenor chip course goose issue fix flagship pho...

# %%
tba3102.data_quality_report(df)
# Out:
#                Comment ID Comment Body   Author    Upvotes          Timestamp Cleaned_Comment
# count                 424          424      424      424.0              424.0             424
# unique                424          411      208        NaN                NaN             410
# top               m9aq3ty    [deleted]  Deleted        NaN                NaN          delete
# freq                    1            9       27        NaN                NaN               9
# mean                  NaN          NaN      NaN   6.365566  1738034579.806604             NaN
# std                   NaN          NaN      NaN  18.393668      533669.761588             NaN
# min                   NaN          NaN      NaN      -41.0       1737895938.0             NaN
# 25%                   NaN          NaN      NaN        1.0       1737903550.5             NaN
# 50%                   NaN          NaN      NaN        2.0       1737915513.5             NaN
# 75%                   NaN          NaN      NaN        5.0       1737958033.5             NaN
# max                   NaN          NaN      NaN      190.0       1742971699.0             NaN
# Data Type          object       object   object      int64            float64          object
# Missing Values          0            0        0          0                  0               0
# Present Values        424          424      424        424                424             424

# %%
tba3102.set_default_pandas_options()

stop_words = nltk.corpus.stopwords.words('english')
wtk = nltk.tokenize.RegexpTokenizer(r'\w+')
wnl = nltk.stem.wordnet.WordNetLemmatizer()

# %%
def normalize_corpus(papers):
    
    norm_papers = []
    
    for paper in papers:
        
        paper = paper.lower()
        paper_tokens = [token.strip() for token in wtk.tokenize(paper)]
        paper_tokens = [wnl.lemmatize(token) for token in paper_tokens if not token.isnumeric()]
        paper_tokens = [token for token in paper_tokens if len(token) > 1]
        paper_tokens = [token for token in paper_tokens if token not in stop_words]
        paper_tokens = list(filter(None, paper_tokens))
        
        if paper_tokens:
            
            norm_papers.append(paper_tokens)
    
    return norm_papers

# %%
def lda_topic_model_coherence_generator(corpus, texts, dictionary, 
                                    start_topic_count=2, end_topic_count=10, step=1, cpus=1):
    
    models = []
    coherence_scores = []

    for topic_nums in tqdm(range(start_topic_count, end_topic_count+1, step)):
        
        lda_model = gensim.models.LdaModel(corpus=corpus, id2word=dictionary,
                                            chunksize=1740, alpha='auto',
                                            eta='auto', random_state=42,
                                            iterations=500, num_topics=topic_nums,
                                            passes=20, eval_every=None)
        
        cv_coherence_model_lda = gensim.models.CoherenceModel(model=lda_model,
                                                            corpus=corpus,
                                                            texts=texts,
                                                            dictionary=dictionary,
                                                            coherence='c_v')
        
        coherence_score = cv_coherence_model_lda.get_coherence()
        coherence_scores.append(coherence_score)
        models.append(lda_model)

    return models, coherence_scores

# %%
descriptions = df["Cleaned_Comment"].to_list()
norm_descriptions = normalize_corpus(descriptions)
# norm_descriptions

# %%
bigram = gensim.models.Phrases(norm_descriptions, min_count=2, threshold=20, delimiter='_')
bigram_model = gensim.models.phrases.Phraser(bigram)

norm_corpus_bigrams = [bigram_model[doc] for doc in norm_descriptions]

# Create a dictionary representation of the documents.
dictionary = gensim.corpora.Dictionary(norm_corpus_bigrams)

# Filter out words that occur less than 2 documents, or more than 60% of the documents.
dictionary.filter_extremes(no_below=2, no_above=0.6)

# Transforming corpus into bag of words vectors
bow_corpus = [dictionary.doc2bow(text) for text in norm_corpus_bigrams]
dictionary.token2id
# Out:
# {'bad': 0,
#  'fancy': 1,
#  'feel': 2,
#  'fix': 3,
#  'like': 4,
#  'open': 5,
#  'really': 6,
#  'samson': 7,
#  'since': 8,
#  'smartphone': 9,
#  'add': 10,
#  'always': 11,
#  'everyone': 12,
#  'fix_pro': 13,
#  'galaxy': 14,
#  'generation': 15,
#  'get': 16,
#  'improve': 17,
#  'indoor': 18,
#  'light': 19,
#  'look': 20,
#  'mostly': 21,
#  'option': 22,
#  'photography': 23,
#  'say': 24,
#  'screen': 25,
#  'second': 26,
#  'still': 27,
#  'take': 28,
#  'thing': 29,
#  'trade': 30,
#  'ultra': 31,
#  'would': 32,
#  'remove': 33,
#  'blow': 34,
#  'gorge': 35,
#  'snapdragon_elite': 36,
#  'tenor': 37,
#  'water': 38,
#  'charge': 39,
#  'chip': 40,
#  'course': 41,
#  'flagship': 42,
#  'goose': 43,
#  'hardware': 44,
#  'issue': 45,
#  'period': 46,
#  'phone': 47,
#  'price': 48,
#  'supper': 49,
#  'camera_hardware': 50,
#  'follow': 51,
#  'go_storage': 52,
#  'list': 53,
#  'mean': 54,
#  'nothing': 55,
#  'outdate': 56,
#  'performance': 57,
#  'siliconcarbon_battery': 58,
#  'son': 59,
#  'start': 60,
#  'use': 61,
#  'well': 62,
#  'yet': 63,
#  'grapheneo': 64,
#  'much': 65,
#  'powerful': 66,
#  'processor': 67,
#  'run': 68,
#  'already': 69,
#  'andros': 70,
#  'apple': 71,
#  'battery': 72,
#  'behind': 73,
#  'company': 74,
#  'compromise': 75,
#  'drop': 76,
#  'even': 77,
#  'ever': 78,
#  'heap': 79,
#  'honestly': 80,
#  'incremental': 81,
#  'insane': 82,
#  'mention': 83,
#  'pathetic': 84,
#  'popular': 85,
#  'see': 86,
#  'silicone_carbon': 87,
#  'stock': 88,
#  'think': 89,
#  'two': 90,
#  'update': 91,
#  'wonder': 92,
#  'year': 93,
#  'camera': 94,
#  'chinese': 95,
#  'choose': 96,
#  'come': 97,
#  'competitive': 98,
#  'consider': 99,
#  'criticism': 100,
#  'criticize': 101,
#  'customizable': 102,
#  'day': 103,
#  'deal': 104,
#  'enough': 105,
#  'especially': 106,
#  'etc': 107,
#  'even_though': 108,
#  'free': 109,
#  'frequently': 110,
#  'good': 111,
#  'huge': 112,
#  'improvement': 113,
#  'inside': 114,
#  'instead': 115,
#  'less': 116,
#  'market': 117,
#  'na': 118,
#  'objective': 119,
#  'offer': 120,
#  'one': 121,
#  'photo': 122,
#  'plenty': 123,
#  'right': 124,
#  'samsung': 125,
#  'snapdragon': 126,
#  'storage': 127,
#  'super': 128,
#  'talk': 129,
#  'tempt': 130,
#  'term': 131,
#  'though': 132,
#  'ton': 133,
#  'top': 134,
#  'upgrade': 135,
#  'version_andros': 136,
#  'wait': 137,
#  'way': 138,
#  'wedlock': 139,
#  'worth': 140,
#  'bar': 141,
#  'go_wrong': 142,
#  'home_screen': 143,
#  'permanent': 144,
#  'prefer': 145,
#  'search': 146,
#  'superior': 147,
#  'buy': 148,
#  'cope': 149,
#  'either': 150,
#  'fact': 151,
#  'game': 152,
#  'guess': 153,
#  'kiss': 154,
#  'life': 155,
#  'literally': 156,
#  'moment': 157,
#  'move': 158,
#  'never': 159,
#  'object': 160,
#  'people': 161,
#  'pet': 162,
#  'shoot': 163,
#  'sorry': 164,
#  'try': 165,
#  'understand': 166,
#  'new': 167,
#  'release': 168,
#  'send': 169,
#  'edit': 170,
#  'expensive': 171,
#  'may': 172,
#  'amazon': 173,
#  'barely': 174,
#  'bc': 175,
#  'buck': 176,
#  'case': 177,
#  'consumer': 178,
#  'cost': 179,
#  'couture': 180,
#  'design': 181,
#  'device': 182,
#  'difference': 183,
#  'different': 184,
#  'double': 185,
#  'excite': 186,
#  'find': 187,
#  'functional': 188,
#  'go': 189,
#  'inferior': 190,
#  'internal': 191,
#  'know': 192,
#  'least': 193,
#  'love': 194,
#  'medium': 195,
#  'model': 196,
#  'money': 197,
#  'old': 198,
#  'opinion': 199,
#  'pipe': 200,
#  'point': 201,
#  'price_increase': 202,
#  'rather': 203,
#  'repeat': 204,
#  'report': 205,
#  'seem': 206,
#  'silicon': 207,
#  'square': 208,
#  'standard': 209,
#  'strange': 210,
#  'time': 211,
#  'turn': 212,
#  'user': 213,
#  'seriously': 214,
#  'comparison': 215,
#  'make': 216,
#  'actually': 217,
#  'ask': 218,
#  'cheap': 219,
#  'decent': 220,
#  'every': 221,
#  'feature': 222,
#  'give': 223,
#  'offering': 224,
#  'onerous': 225,
#  'pro': 226,
#  'set': 227,
#  'single': 228,
#  'software': 229,
#  'anything': 230,
#  'ball': 231,
#  'care': 232,
#  'crazy': 233,
#  'enjoy': 234,
#  'great': 235,
#  'lot': 236,
#  'notice': 237,
#  'plus': 238,
#  'pretty': 239,
#  'bloatware': 240,
#  'far': 241,
#  'mio': 242,
#  'pick': 243,
#  'recommend': 244,
#  'agree': 245,
#  'compare': 246,
#  'completely': 247,
#  'forward': 248,
#  'gaze': 249,
#  'heavy': 250,
#  'however': 251,
#  'sd': 252,
#  'shit': 253,
#  'solid': 254,
#  'mess': 255,
#  'need': 256,
#  'overhear': 257,
#  'refresh': 258,
#  'also': 259,
#  'gen': 260,
#  'loss': 261,
#  'skin': 262,
#  'zero': 263,
#  'ago': 264,
#  'couple': 265,
#  'fine': 266,
#  'kind': 267,
#  'motor': 268,
#  'slab': 269,
#  'technology': 270,
#  'week': 271,
#  'work': 272,
#  'hate': 273,
#  'pull': 274,
#  'win': 275,
#  'big': 276,
#  'connect': 277,
#  'mine': 278,
#  'anyone': 279,
#  'base': 280,
#  'battery_life': 281,
#  'bit': 282,
#  'change': 283,
#  'dig': 284,
#  'document': 285,
#  'download': 286,
#  'end': 287,
#  'experience': 288,
#  'joke': 289,
#  'large': 290,
#  'last': 291,
#  'last_year': 292,
#  'leave': 293,
#  'little': 294,
#  'long': 295,
#  'might': 296,
#  'mind': 297,
#  'month': 298,
#  'past': 299,
#  'research': 300,
#  'safe': 301,
#  'security': 302,
#  'series': 303,
#  'short': 304,
#  'size': 305,
#  'small': 306,
#  'something': 307,
#  'store': 308,
#  'story': 309,
#  'suck': 310,
#  'swap': 311,
#  'tell': 312,
#  'terrible': 313,
#  'thank': 314,
#  'warn': 315,
#  'without': 316,
#  'definitely': 317,
#  'yeah': 318,
#  'hard': 319,
#  'keep': 320,
#  'plan': 321,
#  'xiaomi': 322,
#  'easily': 323,
#  'lack': 324,
#  'speck': 325,
#  'hand': 326,
#  'justify': 327,
#  'variant': 328,
#  'dedicate': 329,
#  'headphone': 330,
#  'jack': 331,
#  'late': 332,
#  'nice': 333,
#  'plug': 334,
#  'post': 335,
#  'want': 336,
#  'clear': 337,
#  'ink': 338,
#  'rock': 339,
#  'ah': 340,
#  'extra': 341,
#  'side': 342,
#  'teach': 343,
#  'modern': 344,
#  'oo': 345,
#  'act': 346,
#  'back': 347,
#  'front': 348,
#  'full': 349,
#  'weird': 350,
#  'half': 351,
#  'speed': 352,
#  'spend': 353,
#  'allow': 354,
#  'custom': 355,
#  'secure': 356,
#  'vive': 357,
#  'another': 358,
#  'call': 359,
#  'disable': 360,
#  'everything': 361,
#  'lead': 362,
#  'lower': 363,
#  'miss': 364,
#  'number': 365,
#  'smart': 366,
#  'yes': 367,
#  'flurry': 368,
#  'next': 369,
#  'shutter': 370,
#  'worst': 371,
#  'away': 372,
#  'similar': 373,
#  'early': 374,
#  'buggy': 375,
#  'defeat': 376,
#  'lose': 377,
#  'overall': 378,
#  'quality': 379,
#  'trash': 380,
#  'ecosystem': 381,
#  'okay': 382,
#  'stop': 383,
#  'stupid': 384,
#  'whatever': 385,
#  'child': 386,
#  'comment': 387,
#  'low': 388,
#  'randroid': 389,
#  'rarely': 390,
#  'bake': 391,
#  'believe': 392,
#  'bug': 393,
#  'compete': 394,
#  'damn': 395,
#  'go_back': 396,
#  'incredible': 397,
#  'mad': 398,
#  'many': 399,
#  'near': 400,
#  'organ': 401,
#  'part': 402,
#  'perfect': 403,
#  'quite': 404,
#  'service': 405,
#  'shame': 406,
#  'simply': 407,
#  'system': 408,
#  'unique': 409,
#  'onto': 410,
#  'brand': 411,
#  'could': 412,
#  'save': 413,
#  'despite': 414,
#  'efficiency': 415,
#  'power': 416,
#  'real': 417,
#  'sub': 418,
#  'wildly': 419,
#  'wrong': 420,
#  'stroll': 421,
#  'weak': 422,
#  'animal': 423,
#  'cloth': 424,
#  'play': 425,
#  'wreck': 426,
#  'become': 427,
#  'heating': 428,
#  'music': 429,
#  'navigation': 430,
#  'strong': 431,
#  'possibly': 432,
#  'cup': 433,
#  'man': 434,
#  'record': 435,
#  'shape': 436,
#  'snapdragon_gen': 437,
#  'heavily': 438,
#  'unless': 439,
#  'average': 440,
#  'mode': 441,
#  'qualcom': 442,
#  'anyway': 443,
#  'genshin': 444,
#  'impact': 445,
#  'mate': 446,
#  'adjust': 447,
#  'although': 448,
#  'amazing': 449,
#  'cause': 450,
#  'india': 451,
#  'reason': 452,
#  'thirty': 453,
#  'wan': 454,
#  'equivalent': 455,
#  'hold': 456,
#  'par': 457,
#  'provide': 458,
#  'correct': 459,
#  'choice': 460,
#  'green': 461,
#  'line': 462,
#  'close': 463,
#  'family': 464,
#  'favor': 465,
#  'happy': 466,
#  'picture': 467,
#  'question': 468,
#  'achieve': 469,
#  'manage': 470,
#  'matter': 471,
#  'picturevideo': 472,
#  'somehow': 473,
#  'technical': 474,
#  'let': 475,
#  'people_willing': 476,
#  'almost': 477,
#  'high': 478,
#  'resolution': 479,
#  'slot': 480,
#  'year_old': 481,
#  'delete': 482,
#  'blur': 483,
#  'everywhere': 484,
#  'photograph': 485,
#  'ugly': 486,
#  'anymore': 487,
#  'tireless': 488,
#  'additional': 489,
#  'battery_become': 490,
#  'develop': 491,
#  'image': 492,
#  'introduce': 493,
#  'norm': 494,
#  'process': 495,
#  'sale': 496,
#  'soon': 497,
#  'sort': 498,
#  'sure': 499,
#  'vendetta': 500,
#  'wide': 501,
#  'heat': 502,
#  'launch': 503,
#  'weight': 504,
#  'dreadful': 505,
#  'wallpaper': 506,
#  'mountain': 507,
#  'product': 508,
#  'sludgeware': 509,
#  'worry': 510,
#  'first': 511,
#  'force_upon': 512,
#  'instal': 513,
#  'nova_launch': 514,
#  'owner': 515,
#  'customization': 516,
#  'true': 517,
#  'alone': 518,
#  'lawless': 519,
#  'native': 520,
#  'recorder': 521,
#  'ahead': 522,
#  'bloat': 523,
#  'extensive': 524,
#  'default': 525,
#  'fan': 526,
#  'flat': 527,
#  'good_lock': 528,
#  'icon': 529,
#  'ridiculous': 530,
#  'thankful': 531,
#  'wish': 532,
#  'break': 533,
#  'honor': 534,
#  'may_battery': 535,
#  'claim': 536,
#  'competition': 537,
#  'credit': 538,
#  'else': 539,
#  'horrible': 540,
#  'hour': 541,
#  'kill': 542,
#  'listen': 543,
#  'occasional': 544,
#  'ship': 545,
#  'exyno': 546,
#  'basically': 547,
#  'discount': 548,
#  'glad': 549,
#  'bone': 550,
#  'easy': 551,
#  'pay': 552,
#  'common': 553,
#  'happen': 554,
#  'ability': 555,
#  'access': 556,
#  'depend': 557,
#  'mo': 558,
#  'person': 559,
#  'reduce': 560,
#  'spasm_call': 561,
#  'around': 562,
#  'complaint': 563,
#  'mint': 564,
#  'mobile': 565,
#  'catch': 566,
#  'manufacturer': 567,
#  'sheet': 568,
#  'space': 569,
#  'value': 570,
#  'non': 571,
#  'replace': 572,
#  'type': 573,
#  'lighter': 574,
#  'pretty_much': 575,
#  'hang': 576,
#  'considerably': 577,
#  'contract': 578,
#  'except': 579,
#  'live': 580,
#  'place': 581,
#  'able': 582,
#  'crack': 583,
#  'hear': 584,
#  'assume': 585,
#  'customer': 586,
#  'beat': 587,
#  'disappointment': 588,
#  'europe': 589,
#  'example': 590,
#  'firefox': 591,
#  'lastly': 592,
#  'prove': 593,
#  'push': 594,
#  'sell': 595,
#  'smooth': 596,
#  'stick': 597,
#  'yep': 598,
#  'camera_assistant': 599,
#  'complete': 600,
#  'funny': 601,
#  'home': 602,
#  'inconsistent': 603,
#  'mid': 604,
#  'network': 605,
#  'refuse': 606,
#  'require': 607,
#  'room': 608,
#  'shutter_law': 609,
#  'stand': 610,
#  'magic': 611,
#  'minor': 612,
#  'annoying': 613,
#  'band': 614,
#  'eh': 615,
#  'fanboy': 616,
#  'aside': 617,
#  'edge': 618,
#  'immediately': 619,
#  'lie': 620,
#  'midrange': 621,
#  'ok': 622,
#  'premium': 623,
#  'probably': 624,
#  'range': 625,
#  'regard': 626,
#  'someone': 627,
#  'efficient': 628,
#  'clean': 629,
#  'due': 630,
#  'fa': 631,
#  'handle': 632,
#  'review': 633,
#  'purchase': 634,
#  'clock': 635,
#  'higher': 636,
#  'make_sense': 637,
#  'embarrass': 638,
#  'andros_auto': 639,
#  'map': 640,
#  'build': 641,
#  'internet': 642,
#  'level': 643,
#  'lock': 644,
#  'waste': 645,
#  'accomplish': 646,
#  'fast': 647,
#  'friend': 648,
#  'task': 649,
#  'video': 650,
#  'behavior': 651,
#  'girl': 652,
#  'nexus': 653,
#  'ram': 654,
#  'switch': 655,
#  'hope': 656,
#  'learn': 657,
#  'ai': 658,
#  'approach': 659,
#  'certain': 660,
#  'describe': 661,
#  'exact': 662,
#  'exactly': 663,
#  'limit': 664,
#  'outcome': 665,
#  'potential': 666,
#  'result': 667,
#  'throttle': 668,
#  'appeal': 669,
#  'benefit': 670,
#  'bother': 671,
#  'context': 672,
#  'raw': 673,
#  'tradeoff': 674,
#  'instance': 675,
#  'major': 676,
#  'necessarily': 677,
#  'problem': 678,
#  'wait_apple': 679,
#  'bet': 680,
#  'expect': 681,
#  'extremely': 682,
#  'long_time': 683,
#  'across': 684,
#  'blind': 685,
#  'frame': 686,
#  'freeze': 687,
#  'gram': 688,
#  'install': 689,
#  'less_fault': 690,
#  'motion': 691,
#  'noise': 692,
#  'shutter_speed': 693,
#  'smear': 694,
#  'barebone': 695,
#  'beg': 696,
#  'slow': 697,
#  'file': 698,
#  'format': 699,
#  'possible': 700,
#  'proprietary': 701,
#  'show': 702,
#  'force': 703,
#  'oh': 704,
#  'generally': 705,
#  'rd_party': 706,
#  'daily': 707,
#  'downgrade': 708,
#  'every_brand': 709,
#  'exclusive': 710,
#  'invest': 711,
#  'jan': 712,
#  'release_come': 713,
#  'absolutely': 714,
#  'bud': 715,
#  'fair': 716,
#  'include': 717,
#  'extremely_buggy': 718,
#  'thirdparty_launch': 719,
#  'bottom': 720,
#  'hide': 721,
#  'nodule': 722,
#  'childish': 723,
#  'name': 724,
#  'certainly': 725,
#  'read': 726,
#  'modification': 727,
#  'ratification': 728,
#  'uninstale': 729,
#  'job': 730,
#  'carrier': 731,
#  'support': 732,
#  'law': 733,
#  'display': 734,
#  'restore': 735,
#  'finally': 736,
#  'fun': 737,
#  'otherwise': 738,
#  'compact': 739,
#  'fold': 740,
#  'max': 741,
#  'spasm': 742,
#  'speak': 743,
#  'text': 744,
#  'hell': 745,
#  'attempt': 746,
#  'explode': 747,
#  'realm': 748,
#  'argue': 749,
#  'check': 750,
#  'unlimited': 751,
#  'version': 752,
#  'watch': 753,
#  'budget': 754,
#  'worldwide': 755,
#  'graphene': 756,
#  'curve': 757,
#  'genuinely': 758,
#  'significantly': 759,
#  'available': 760,
#  'conversation': 761,
#  'date': 762,
#  'law_behind': 763,
#  'load': 764,
#  'outside': 765,
#  'simple': 766,
#  'testing': 767,
#  'button': 768,
#  'honest': 769,
#  'keyboard': 770,
#  'note': 771,
#  'garage': 772,
#  'increase': 773,
#  'bow': 774,
#  'government': 775,
#  'maybe': 776,
#  'multiple': 777,
#  'must': 778,
#  'cup_performance': 779,
#  'op': 780,
#  'sit': 781,
#  'snap': 782,
#  'apart': 783,
#  'boat': 784,
#  'book': 785,
#  'bottleneck': 786,
#  'deserve': 787,
#  'doubt': 788,
#  'frankly': 789,
#  'ironically': 790,
#  'stuff': 791,
#  'unlocked_botloader': 792,
#  'whether': 793,
#  'botloader': 794,
#  'full_control': 795,
#  'sell_point': 796,
#  'perform': 797,
#  'downvote': 798,
#  'car': 799,
#  'hot': 800,
#  'whole': 801,
#  'mediate': 802,
#  'beta': 803,
#  'enable': 804,
#  'focus': 805,
#  'noticeable': 806,
#  'program': 807,
#  'rate': 808,
#  'spot': 809,
#  'suppose': 810,
#  'promotion': 811,
#  'reality': 812,
#  'equally': 813,
#  'regular': 814,
#  'aware': 815,
#  'setting': 816,
#  'tend': 817,
#  'usually': 818,
#  'main': 819,
#  'sd_card': 820,
#  'stream': 821,
#  'cloud': 822,
#  'resolve': 823,
#  'click': 824,
#  'drawer': 825,
#  'homage': 826,
#  'lately': 827,
#  'particularly': 828,
#  'pas': 829,
#  'press': 830,
#  'proposition': 831,
#  'quick': 832,
#  'third_party': 833,
#  'exclusively': 834,
#  'iso': 835,
#  'recently': 836,
#  'relatively': 837,
#  'history': 838,
#  'write': 839,
#  'issue_gesture': 840,
#  'billion': 841,
#  'bag': 842,
#  'niagara': 843,
#  'nova': 844,
#  'lawnchair': 845,
#  'amount': 846,
#  'deal_breaker': 847,
#  'gesture': 848,
#  'advice': 849,
#  'page': 850,
#  'nowadays': 851,
#  'baby': 852,
#  'ra': 853,
#  'fit': 854,
#  'luck': 855,
#  'email': 856,
#  'microsoft': 857,
#  'useful': 858,
#  'view': 859,
#  'student': 860,
#  'remain': 861,
#  'premium_price': 862,
#  'bright': 863,
#  'condition': 864,
#  'creator': 865,
#  'favorable': 866,
#  'guy': 867,
#  'lighting': 868,
#  'showcase': 869,
#  'suhtpsyoutuberfytjoyalksibrkalaudmsirt': 870,
#  'twitch': 871,
#  'tap': 872,
#  'unlock': 873,
#  'void_warranty': 874,
#  'current': 875,
#  'mm': 876,
#  'steal': 877,
#  'blow_proportion': 878,
#  'satisfy': 879,
#  'wife': 880,
#  'content': 881,
#  'produce': 882,
#  'continue': 883,
#  'grass': 884,
#  'present': 885,
#  'box': 886,
#  'expectation': 887,
#  'grid': 888,
#  'interface': 889,
#  'clink': 890,
#  'comentmesagei': 891,
#  'hateful': 892,
#  'informationhtpswreditcomrandroidwikirulesandregswiki_no_ofensivec_hatefulc_or_lowefort_coment': 893,
#  'linkhtpwreditcomesagecomposetofrfandroidsubjectabout': 894,
#  'lowefort': 895,
#  'message': 896,
#  'offensive': 897,
#  'operator': 898,
#  'please': 899,
#  'reditquetehtpswredithelpcomencategoriesreditreditbasicsrediquete': 900,
#  'rule': 901,
#  'wiki': 902,
#  'control': 903,
#  'developer': 904,
#  'exist': 905,
#  'letter': 906,
#  'new_version': 907,
#  'organize': 908,
#  'relate': 909,
#  'sometimes': 910,
#  'closing': 911,
#  'delay': 912,
#  'fully': 913,
#  'responsive': 914,
#  'reinstate': 915,
#  'state': 916,
#  'explain': 917,
#  'whatsap': 918,
#  'thick': 919,
#  'contact': 920,
#  'installation': 921,
#  'user_experience': 922,
#  'unable': 923,
#  'reliable': 924,
#  'article': 925,
#  'beyond': 926,
#  'animation': 927,
#  'customize': 928,
#  'limitation': 929,
#  'reference': 930,
#  'de': 931,
#  'original': 932,
#  'useless': 933,
#  'perfectly': 934,
#  'sonya': 935,
#  'bring': 936,
#  'awful': 937,
#  'wipe': 938,
#  'proof': 939}

# %%
lda_models, coherence_scores = lda_topic_model_coherence_generator(corpus=bow_corpus,
                                                                texts=norm_corpus_bigrams,
                                                                dictionary=dictionary,
                                                                start_topic_count=2,
                                                                end_topic_count=10, step=1,
                                                                cpus=16)
# Out:
# 100%|██████████| 9/9 [01:05<00:00,  7.31s/it]

# %%
lda_coherence_df = pd.DataFrame({'Number of Topics': range(2, 11, 1), 'Coherence Score': np.round(coherence_scores, 4)})
lda_coherence_df_top10 = lda_coherence_df.sort_values(by=['Coherence Score'], ascending=False).head(10)
print(lda_coherence_df_top10)
# lda_coherence_df_top10.to_csv("lda_top10.csv")
# Out:
#    Number of Topics  Coherence Score
# 1                 3           0.5999
# 2                 4           0.5931
# 0                 2           0.5715
# 4                 6           0.5575
# 6                 8           0.5567
# 7                 9           0.5544
# 3                 5           0.5501
# 5                 7           0.5490
# 8                10           0.5357

# %%
TOTAL_TOPICS = lda_coherence_df_top10["Number of Topics"].reset_index(drop=True).iloc[0]
TOTAL_TOPICS
# Out:
# 3

# %%
model = gensim.models.LdaModel(corpus=bow_corpus, id2word=dictionary,
                                    chunksize=1740, alpha='auto',
                                    eta='auto', random_state=42,
                                    iterations=500, num_topics=TOTAL_TOPICS,
                                    passes=20, eval_every=None)

# %%
topics = [[(term, round(wt, 3))
                for term, wt in model.show_topic(n, topn=20)]
                    for n in range(0, model.num_topics)]

topics_df = pd.DataFrame([[term for term, wt in topic]
                            for topic in topics],
                        columns = ['Term'+str(i) for i in range(1, 21)],
                        index=['Topic '+str(t) for t in range(1, model.num_topics+1)]).T

topics_df = pd.DataFrame([', '.join([term for term, wt in topic])
                                for topic in topics],
                                columns = ['Terms per Topic'],
                                index=['Topic'+str(t) for t in range(1, model.num_topics+1)])



tm_results = model[bow_corpus]

corpus_topics = [sorted(topics, key=lambda record: -record[1])[0]
                 for topics in tm_results]

# %%
corpus_topic_df = pd.DataFrame()
corpus_topic_df['Document'] = range(0, len(descriptions))
corpus_topic_df['DominantTopic'] = [item[0]+1 for item in corpus_topics]
corpus_topic_df['ContributionPercent'] = [round(item[1]*100, 2) for item in corpus_topics]
corpus_topic_df['TopicDesc'] = [topics_df.iloc[t[0]]['Terms per Topic']
                                    for t in corpus_topics]
corpus_topic_df["Comment Body"] = df["Comment Body"]
corpus_topic_df['Cleaned_Comment'] = df["Cleaned_Comment"]

# %%
corpus_topic_df = corpus_topic_df.sort_values(by=["ContributionPercent"], ascending=False)
corpus_topic_df.to_csv(f"../data/results/{file_name}_topic_modelling.csv")
corpus_topic_df.groupby('DominantTopic').apply(lambda topic_set:( topic_set.sort_values(by=['ContributionPercent'], ascending=False).iloc[0]))
# Out:
# C:\Users\tee_m\AppData\Local\Temp\ipykernel_11556\3136253596.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   corpus_topic_df.groupby('DominantTopic').apply(lambda topic_set:( topic_set.sort_values(by=['ContributionPercent'], ascending=False).iloc[0]))
#                Document  DominantTopic  ContributionPercent                                          TopicDesc                                       Comment Body                                    Cleaned_Comment
# DominantTopic
# 1                   239              1                99.87  samson, fix, well, get, phone, like, one, appl...  Right and honestly like some people might not ...  right honestly like people might care throttle...
# 2                    29              2                99.91  phone, fix, samson, use, get, would, go, goose...  So I started my Journey with a Samsung S9 in 2...  I start journey samson last year last leg offe...
# 3                   245              3                99.91  fix, well, samson, use, get, phone, like, perf...  Well I don't think I would say everything. I m...  well I think I would say everything I mean man...

# %%
corpus_topic_df
# Out:
#      Document  DominantTopic  ContributionPercent                                          TopicDesc                                       Comment Body                                    Cleaned_Comment
# 29         29              2                99.91  phone, fix, samson, use, get, would, go, goose...  So I started my Journey with a Samsung S9 in 2...  I start journey samson last year last leg offe...
# 245       245              3                99.91  fix, well, samson, use, get, phone, like, perf...  Well I don't think I would say everything. I m...  well I think I would say everything I mean man...
# 8           8              2                99.89  phone, fix, samson, use, get, would, go, goose...  The S25 (especially the Ultra) is better. The ...  especially ultra well snapdragon chip inside o...
# 325       325              2                99.87  phone, fix, samson, use, get, would, go, goose...  I mean there are occasional bugs related to th...  I mean occasional bag relate third party launc...
# 126       126              2                99.87  phone, fix, samson, use, get, would, go, goose...  Its.not fanboism as much as it's a disappointm...  itsnot fanboism much disappointment see large ...
# 239       239              1                99.87  samson, fix, well, get, phone, like, one, appl...  Right and honestly like some people might not ...  right honestly like people might care throttle...
# 319       319              1                99.86  samson, fix, well, get, phone, like, one, appl...  Software experience in Pixel has been subpar, ...  software experience fix supper least use case ...
# 208       208              2                99.86  phone, fix, samson, use, get, would, go, goose...  Google is working to upgrade Tensor, but the m...  goose work upgrade tenor major upgrade next ye...
# 14         14              3                99.86  fix, well, samson, use, get, phone, like, perf...  Wow such scrutinizing consumer reports here. /...  scrutinize consumer report honestly I think pl...
# 215       215              2                99.84  phone, fix, samson, use, get, would, go, goose...  For me the fanboying is because of a couple th...  I annoying couple thing fix first non super bu...
# 372       372              3                99.83  fix, well, samson, use, get, phone, like, perf...  Yes this is true and it's evidenced by the fac...  yes true evidence fact niagara nova write lett...
# 101       101              2                99.83  phone, fix, samson, use, get, would, go, goose...  I know on the other sub forums people claim th...  I know sub form people claim pro fix battery i...
# 326       326              2                99.82  phone, fix, samson, use, get, would, go, goose...  Back when I had the Nexus 5x, they stopped bug...  back I nexus x stop bugfixe goose launch suppo...
# 206       206              2                99.81  phone, fix, samson, use, get, would, go, goose...  In hand feel is what matters. I have all 3 dev...  hand feel matter I device home p x x p feel pr...
# 166       166              2                99.80  phone, fix, samson, use, get, would, go, goose...  Wow. An ultrawide camera that's been on other ...  ultrawide camera phone year silicone carbon ba...
# 279       279              2                99.80  phone, fix, samson, use, get, would, go, goose...  Germany. It's 695€ at the cheapest online reta...  germany cheap online retailer onerous addition...
# 300       300              2                99.79  phone, fix, samson, use, get, would, go, goose...  Regular 7 and 8.\n\nI ordered S25 Ultra now, s...  regular I order ultra fun see behave andros au...
# 288       288              2                99.78  phone, fix, samson, use, get, would, go, goose...  I'd like to believe but that guy is a Samsung ...  I would like believe guy samson mobile creator...
# 153       153              3                99.77  fix, well, samson, use, get, phone, like, perf...  I think we have a different approach. Yours is...  I think different approach end result mine exa...
# 157       157              2                99.76  phone, fix, samson, use, get, would, go, goose...  I have a seven year old phone with 128GB of st...  I seven year old phone go storage I still go f...
# 159       159              3                99.75  fix, well, samson, use, get, phone, like, perf...  That's less the fault of the hardware and more...  less fault hardware software samson terrible n...
# 271       271              2                99.74  phone, fix, samson, use, get, would, go, goose...  Every app that is forced upon you and can't be...  every force upon uninstale potential bloatware...
# 419       419              3                99.74  fix, well, samson, use, get, phone, like, perf...  I don't know... \n\nI came from a Pixel 6 & 7,...  I know I come fix I well aware fix ecosystem I...
# 154       154              3                99.73  fix, well, samson, use, get, phone, like, perf...  Lol this is utter nonsense. Phone features peo...  utter nonsense phone feature people desire wor...
# 220       220              3                99.72  fix, well, samson, use, get, phone, like, perf...  This is exactly how I feel about the cameras. ...  exactly I feel camera I get samson charge cust...
# 168       168              2                99.72  phone, fix, samson, use, get, would, go, goose...  >I was able to trade my s22u \n\nSame. Coming ...  I able trade come go pretty big upgrade get ne...
# 240       240              2                99.71  phone, fix, samson, use, get, would, go, goose...  Many people have a tendency to get their phone...  many people tendency get phone phone plan usua...
# 246       246              3                99.69  fix, well, samson, use, get, phone, like, perf...  > Silicone carbon batteries are just becoming ...  silicone carbon battery become norm even thoug...
# 165       165              2                99.68  phone, fix, samson, use, get, would, go, goose...  Honestly my biggest buyers remorse for this ph...  honestly big buyer remorse phone unless image ...
# 230       230              3                99.68  fix, well, samson, use, get, phone, like, perf...  I am not commenting on the SoC. My comment was...  I comment comment around many people would act...
# 296       296              2                99.68  phone, fix, samson, use, get, would, go, goose...  How and when did you get your Pixel 9 Pro from...  get fix pro mm I phone steal start shop phone ...
# 241       241              2                99.68  phone, fix, samson, use, get, would, go, goose...  My old Galaxy Note 9 has 128GB of storage and ...  old galaxy note go storage I use main phone I ...
# 195       195              3                99.68  fix, well, samson, use, get, phone, like, perf...  I can run an LLM locally on my iPhone and freq...  I run locally phone frequently use attempt p m...
# 110       110              2                99.67  phone, fix, samson, use, get, would, go, goose...  you guys are way too caught on specs like this...  gun way catch speck like still use onerous pal...
# 11         11              2                99.66  phone, fix, samson, use, get, would, go, goose...  I never understood people who buy a Samsung an...  I never understand people buy samson try cope ...
# 343       343              2                99.66  phone, fix, samson, use, get, would, go, goose...  I get a few more than your 1-2 per month but n...  I get per month even per week I go week withou...
# 353       353              2                99.66  phone, fix, samson, use, get, would, go, goose...  Yeah, that Twitter guy is a Samsung mobile con...  yeah twitter guy samson mobile content creator...
# 1           1              2                99.66  phone, fix, samson, use, get, would, go, goose...  They said that indoor photography improved thi...  say indoor photography improve generation say ...
# 321       321              2                99.65  phone, fix, samson, use, get, would, go, goose...  Sorry , your comment has been removed: \n\n> R...  sorry comment remove rule \ offensive hateful ...
# 211       211              2                99.65  phone, fix, samson, use, get, would, go, goose...  Agree 100%, Switched from a pixel to an s23 an...  agree switch fix performance increase combine ...
# 119       119              2                99.65  phone, fix, samson, use, get, would, go, goose...  Except the 13R is considerably bigger than the...  except r considerably big heavy well thing mat...
# 367       367              2                99.65  phone, fix, samson, use, get, would, go, goose...  Sorry xsconfused, your comment has been remove...  sorry confuse comment remove rule \ offensive ...
# 305       305              2                99.65  phone, fix, samson, use, get, would, go, goose...  Screens have gotten vastly more efficient over...  screen get lastly efficient year unlike chip w...
# 315       315              2                99.63  phone, fix, samson, use, get, would, go, goose...  They wait on Apple to make the move with prett...  wait apple make move pretty much everything wh...
# 344       344              2                99.63  phone, fix, samson, use, get, would, go, goose...  You can disable chrome, YouTube, Gmail and the...  disable come couture email vast majority goose...
# 273       273              2                99.63  phone, fix, samson, use, get, would, go, goose...  And from the "two of everything" I uninstall G...  two everything I instal goose variant keep sam...
# 264       264              2                99.63  phone, fix, samson, use, get, would, go, goose...  Bad is relatively. If you need professional pi...  bad relatively need professional picture every...
# 400       400              2                99.62  phone, fix, samson, use, get, would, go, goose...  I haven't owned a Samsung phone, but I have he...  I samson phone I hear flavor os candle thirdpa...
# 209       209              1                99.62  samson, fix, well, get, phone, like, one, appl...  I'm still using a Note 8, and I don't really w...  I still use note I really want get something n...
# 7           7              3                99.62  fix, well, samson, use, get, phone, like, perf...  Two of the most popular android phones both wi...  two popular andros phone heap compromise insan...
# 351       351              2                99.60  phone, fix, samson, use, get, would, go, goose...  And my old Nokia E72 could do 5 days on a 1200...  old nikita e could day may battery point sell ...
# 156       156              2                99.59  phone, fix, samson, use, get, would, go, goose...  The problem is that there is an option. You ca...  problem option buy pay get go variant case fac...
# 377       377              1                99.59  samson, fix, well, get, phone, like, one, appl...  When you setup your iPhone, they come with all...  set phone come apple reinstate thing I conside...
# 137       137              3                99.59  fix, well, samson, use, get, phone, like, perf...  Yep, just clean installed the latest OS and me...  yep clean instal late os measure fas mostly ar...
# 73         73              3                99.59  fix, well, samson, use, get, phone, like, perf...  > Uses outdated camera hardware.\n\n> Does not...  use outdate camera hardware use siliconcarbon ...
# 313       313              1                99.58  samson, fix, well, get, phone, like, one, appl...  Great hardware at very competitive prices, but...  great hardware competitive price everywhere I ...
# 175       175              1                99.58  samson, fix, well, get, phone, like, one, appl...  I switched from a Phxel to a Galaxy S23 becaus...  I switch pfuel galaxy time I want buy gigantic...
# 146       146              1                99.58  samson, fix, well, get, phone, like, one, appl...  It's not just about performance, which might n...  performance might matter much future also mode...
# 312       312              2                99.57  phone, fix, samson, use, get, would, go, goose...  Great hardware, but both Google and Samsung ha...  great hardware goose samson year software supp...
# 379       379              2                99.57  phone, fix, samson, use, get, would, go, goose...  Yeah, I once bought an Iphone and was kinda hy...  yeah I buy phone kind hope use message contact...
# 397       397              2                99.57  phone, fix, samson, use, get, would, go, goose...  Yeah I definitely would've bought a OP 13 if I...  yeah I definitely would buy op I already ultra...
# 111       111              1                99.56  samson, fix, well, get, phone, like, one, appl...  Let me guess you are the type of people who th...  let I guess type people think non removable co...
# 410       410              1                99.56  samson, fix, well, get, phone, like, one, appl...  Lol dude yes the 0.01% of owners who consider ...  due yes owner consider dedicate samson galaxy ...
# 394       394              2                99.55  phone, fix, samson, use, get, would, go, goose...  Switch to pro mode and use the correct shutter...  switch pro mode use correct shutter speed I ge...
# 39         39              2                99.55  phone, fix, samson, use, get, would, go, goose...  Those of you who obsess over phones or act lik...  abscess phone act like every new one pack full...
# 406       406              2                99.55  phone, fix, samson, use, get, would, go, goose...  You still have choice.   You just go get what ...  still choice go get want lot people like want ...
# 248       248              2                99.55  phone, fix, samson, use, get, would, go, goose...  > All phones released, and upcoming by every o...  phone release come every brand aside samson go...
# 43         43              2                99.55  phone, fix, samson, use, get, would, go, goose...  Yes you can. Samsung insists on automatically ...  yes samson insist automatically lower ringtone...
# 422       422              1                99.54  samson, fix, well, get, phone, like, one, appl...  custom launchers dont give their own app switc...  custom launch give switch homage I launch twit...
# 314       314              1                99.54  samson, fix, well, get, phone, like, one, appl...  Of course they're waiting for apple. They didn...  course wait apple remove headphone jack charge...
# 265       265              2                99.53  phone, fix, samson, use, get, would, go, goose...  Oh yea I love OneUI. I went to iPhone in 2023,...  oh yea I love one I go phone ra probably go ba...
# 202       202              2                99.53  phone, fix, samson, use, get, would, go, goose...  I don't know where you live, but in the US, yo...  I know live get r watch r ship I get unlimited...
# 71         71              2                99.53  phone, fix, samson, use, get, would, go, goose...  >Pixel is not a flagship phone period. \n\n\nI...  fix flagship phone period photography flagship...
# 162       162              1                99.51  samson, fix, well, get, phone, like, one, appl...  Consequences of extremely heavy post processin...  consequence extremely heavy post process raw f...
# 160       160              2                99.50  phone, fix, samson, use, get, would, go, goose...  Yeah its mind boggling how bad Samsung cam is ...  yeah mind beg bad samson I fix exactly reason ...
# 360       360              3                99.49  fix, well, samson, use, get, phone, like, perf...  I did hear the regular 7 had pretty bad batter...  I hear regular pretty bad battery life pro tir...
# 363       363              1                99.49  samson, fix, well, get, phone, like, one, appl...  Don't have the 13 myself but I am using the 12...  I use r honestly bad colorosoxygenos might nee...
# 262       262              1                99.49  samson, fix, well, get, phone, like, one, appl...  Long click the notification and open the apps ...  long click ratification open permission page s...
# 36         36              2                99.48  phone, fix, samson, use, get, would, go, goose...  Ah, the classic tech dilemma: Samsung Galaxy S...  ah classic teach dilemma samson galaxy goose f...
# 380       380              2                99.48  phone, fix, samson, use, get, would, go, goose...  Weight and thickness are a choice. They chose ...  weight thickness choice choose instead battery...
# 131       131              2                99.48  phone, fix, samson, use, get, would, go, goose...  Eh, I've used Pixel, Samsung, and Oneplus over...  eh I use fix samson onerous year every year in...
# 266       266              2                99.48  phone, fix, samson, use, get, would, go, goose...  They shoud be. I'm surprised at how much they ...  I surprised much give I never na buy honor pho...
# 53         53              2                99.48  phone, fix, samson, use, get, would, go, goose...  Yeah honestly there's plenty of criticism for ...  yeah honestly plenty criticism phone I think c...
# 414       414              2                99.48  phone, fix, samson, use, get, would, go, goose...  Pixel 7 pro, pixel 8 pro and now pixel 9 pro x...  fix pro fix pro fix pro nova launch late beta ...
# 213       213              2                99.48  phone, fix, samson, use, get, would, go, goose...  The pixel 9 pro beat both the iPhone 16 and th...  fix pro beat phone galaxy battery test result ...
# 28         28              3                99.47  fix, well, samson, use, get, phone, like, perf...  So I know mine are old, but my biggest issue w...  I know mine old big issue fix vs I get fix con...
# 17         17              3                99.47  fix, well, samson, use, get, phone, like, perf...  Pixel phones are not worth the money. If they ...  fix phone worth money price pro actually decen...
# 19         19              3                99.45  fix, well, samson, use, get, phone, like, perf...  Don't really have a ball in this game, got the...  really ball game get fix plus deal I enjoy lot...
# 21         21              1                99.45  samson, fix, well, get, phone, like, one, appl...  I agree that tensor and Snapdragon are complet...  I agree tenor snapdragon completely different ...
# 311       311              1                99.45  samson, fix, well, get, phone, like, one, appl...  Definitely are improving at much faster pace c...  definitely improve much fast pace compare sams...
# 269       269              2                99.45  phone, fix, samson, use, get, would, go, goose...  I literally just traded in a 3 year s22u and g...  I literally trade year get plus bud pro like r...
# 176       176              2                99.45  phone, fix, samson, use, get, would, go, goose...  Work gave me a Samsung phone. Even though I un...  work give I samson phone even though I uninsta...
# 108       108              3                99.43  fix, well, samson, use, get, phone, like, perf...  Worth depends on the person. For me, the Pixel...  worth depend person I fix get least spasm call...
# 31         31              2                99.42  phone, fix, samson, use, get, would, go, goose...  Just bought a pixel 9 for 650€ but I'm finding...  buy fix I find hard get use software come xiao...
# 201       201              2                99.42  phone, fix, samson, use, get, would, go, goose...  Yeah that's true, if someone wants a smaller p...  yeah true someone want small phone limit choic...
# 356       356              1                99.42  samson, fix, well, get, phone, like, one, appl...  It is full control because Google makes it eas...  full control goose make easy clock botloader c...
# 200       200              2                99.42  phone, fix, samson, use, get, would, go, goose...  I don't hang out here, I check in once in a wh...  I hang I check see go lot different people arg...
# 150       150              1                99.42  samson, fix, well, get, phone, like, one, appl...  Nexus line was superior hardware, just had a w...  nexus line superior hardware weak camera low m...
# 127       127              2                99.42  phone, fix, samson, use, get, would, go, goose...  Competition is good.  It's great that within a...  competition good great within andros user two ...
# 55         55              3                99.40  fix, well, samson, use, get, phone, like, perf...  You're getting down voted but you're not wrong...  get vote wrong tenor g snapdragon elite wildly...
# 109       109              2                99.38  phone, fix, samson, use, get, would, go, goose...  I got my pixel 9 pro for $300 around thanksgiv...  I get fix pro around thanksgive mint mobile in...
# 106       106              2                99.38  phone, fix, samson, use, get, would, go, goose...  Pay more to get last year's phone?\n\nWith pre...  pay get last year phone recorder bone discount...
# 346       346              2                99.38  phone, fix, samson, use, get, would, go, goose...  Better would be just getting one and not two. ...  well would get one two problem samson phone ph...
# 102       102              2                99.38  phone, fix, samson, use, get, would, go, goose...  S25 with preorder deals are cheaper than S24 f...  recorder deal cheap reputable seller though un...
# 164       164              2                99.38  phone, fix, samson, use, get, would, go, goose...  Came back to Android after two iPhones (XR and...  come back andros two phone buy thing make I mi...
# 76         76              2                99.38  phone, fix, samson, use, get, would, go, goose...  My Samsung A52 that's almost 4 years old has 1...  samson almost year old go storage sd slot I wo...
# 104       104              3                99.37  fix, well, samson, use, get, phone, like, perf...  They cost basically the same at my companies s...  cost basically company service provider I get ...
# 407       407              3                99.37  fix, well, samson, use, get, phone, like, perf...  Yeah older versions generally get cracked, but...  yeah old version generally get crack like way ...
# 227       227              1                99.36  samson, fix, well, get, phone, like, one, appl...  Which Pixel do you have ? I have a Pixel 7 Pro...  fix I fix pro I live india whole year hot basi...
# 249       249              3                99.34  fix, well, samson, use, get, phone, like, perf...  Where is it written that Samsung has to be fir...  write samson first adopt new teach I think pro...
# 284       284              2                99.34  phone, fix, samson, use, get, would, go, goose...  The G4 is fine for you because you're the kind...  g fine kind user would benefit fine midrange s...
# 74         74              2                99.34  phone, fix, samson, use, get, would, go, goose...  > Still starting with 128GB of storage. \n\non...  still start go storage base ultra start go sto...
# 270       270              3                99.34  fix, well, samson, use, get, phone, like, perf...  I haven't had as much luck with them in the pa...  I much luck past I also work partner use saums...
# 47         47              2                99.34  phone, fix, samson, use, get, would, go, goose...  Samsung makes the best phone overall \n\nPixel...  samson make well phone overall fix quality tra...
# 49         49              2                99.34  phone, fix, samson, use, get, would, go, goose...  I didn't realize there was a fanboy divide ins...  I realize fancy divide inside andros ecosystem...
# 369       369              2                99.34  phone, fix, samson, use, get, would, go, goose...  Fair enough.  I remember issues with my Pixel ...  fair enough I remember issue fix nova seem sho...
# 333       333              2                99.34  phone, fix, samson, use, get, would, go, goose...  How do I get lawnchair to work? I downloaded i...  I get lawnchair work I download play store see...
# 289       289              1                99.33  samson, fix, well, get, phone, like, one, appl...  What are you even talking about? If you shoot ...  even talk shoot camera law take take photo rid...
# 61         61              1                99.33  samson, fix, well, get, phone, like, one, appl...  Idk man, [Infinity Nikki](https://x.com/pearpa...  ink man infinity nikihtpsxcompearpal_nikistatu...
# 219       219              3                99.30  fix, well, samson, use, get, phone, like, perf...  No kidding. I had a Pixel 6a for like a week. ...  bidding I fix like week thing feel bad op most...
# 323       323              2                99.29  phone, fix, samson, use, get, would, go, goose...  Yeah at least on OnePlus phones, there is real...  yeah least onerous phone really bad lately iss...
# 172       172              2                99.29  phone, fix, samson, use, get, would, go, goose...  And no option to hide the navigation pill\n\nS...  option hide navigation pill samson allow use g...
# 69         69              1                99.29  samson, fix, well, get, phone, like, one, appl...  That's why the Pixel A lineup is much better. ...  fix line much well flagship line battery issue...
# 322       322              2                99.29  phone, fix, samson, use, get, would, go, goose...  I literally said I'm invested in the ecosystem...  I literally say I invest ecosystem I use heap ...
# 258       258              2                99.29  phone, fix, samson, use, get, would, go, goose...  Not being able to hide the navigation bar is a...  able hide navigation bar deal breaker I litera...
# 398       398              2                99.29  phone, fix, samson, use, get, would, go, goose...  It’s probably closer to 1%. There are 3-4 bill...  probably close billion active andros user worl...
# 285       285              2                99.29  phone, fix, samson, use, get, would, go, goose...  >Google is working to upgrade Tensor, but the ...  goose work upgrade tenor major upgrade next ye...
# 277       277              1                99.29  samson, fix, well, get, phone, like, one, appl...  52% of 6500 is around 3400mAh. Thats still les...  around may still less may also realm big displ...
# 294       294              1                99.29  samson, fix, well, get, phone, like, one, appl...  pixel phones are known for  limited customisat...  fix phone know limit customisation limit featu...
# 20         20              2                99.29  phone, fix, samson, use, get, would, go, goose...  Picked up a Pixel 9 Pro and just loving the ph...  pick fix pro love phone far I would recommend ...
# 24         24              2                99.29  phone, fix, samson, use, get, would, go, goose...  just got moto razr couple of weeks ago. Kinda ...  get motor razor couple week ago kind slab rega...
# 187       187              2                99.29  phone, fix, samson, use, get, would, go, goose...  Man I really hope the X9c is also $300 when Ho...  man I really hope c also honor finally start s...
# 267       267              2                99.29  phone, fix, samson, use, get, would, go, goose...  And? You can still fit a 5000 mah battery in a...  still fit may battery screen phone compact als...
# 339       339              3                99.26  fix, well, samson, use, get, phone, like, perf...  I should have explained myself better, the ave...  I explain well average user much happy fix cam...
# 5           5              3                99.26  fix, well, samson, use, get, phone, like, perf...  > Best Tensor performance yet \n\nThat means n...  well tenor performance yet mean nothing follow...
# 144       144              3                99.26  fix, well, samson, use, get, phone, like, perf...  My Pixel is coughing hard managing Android aut...  fix cough hard manage andros auto map specify ...
# 155       155              1                99.25  samson, fix, well, get, phone, like, one, appl...  How it's achieved can matter in some cases for...  achieve matter case instance battery life batt...
# 354       354              2                99.24  phone, fix, samson, use, get, would, go, goose...  Battery size of a 4 yerar old phone, cameras a...  battery size year old phone camera year old ch...
# 304       304              2                99.24  phone, fix, samson, use, get, would, go, goose...  Ah, another pixel fanboy justifying their expe...  ah another fix fancy justify expensive yet mid...
# 329       329              2                99.24  phone, fix, samson, use, get, would, go, goose...  Third party launchers are still not fully comp...  third party launch still fully compatible gest...
# 85         85              2                99.24  phone, fix, samson, use, get, would, go, goose...  Also the weight. I moved from Pixel 5 to 9 pro...  also weight I move fix pro day ago I hate weig...
# 174       174              2                99.24  phone, fix, samson, use, get, would, go, goose...  I miss those times when each icon has its shap...  I miss time icon shape without circular square...
# 193       193              3                99.21  fix, well, samson, use, get, phone, like, perf...  I love Pixels don’t get me wrong. Best Android...  I love pipe get I wrong well andros opinion as...
# 238       238              3                99.21  fix, well, samson, use, get, phone, like, perf...  It's still winning a lot of awards and compari...  still win lot award comparison time well speck...
# 306       306              3                99.21  fix, well, samson, use, get, phone, like, perf...  Lol where did u even get that number from? Bat...  u even get number battery usage screen depend ...
# 145       145              3                99.21  fix, well, samson, use, get, phone, like, perf...  I mean its an objective fact that the Tensor g...  I mean objective fact tenor g like level hones...
# 225       225              2                99.18  phone, fix, samson, use, get, would, go, goose...  There is not, there is however a real problem ...  however real problem samson phone terrible cap...
# 309       309              2                99.18  phone, fix, samson, use, get, would, go, goose...  Why would anyone send a video to someone?  Lik...  would anyone send video someone like million r...
# 250       250              2                99.18  phone, fix, samson, use, get, would, go, goose...  For a while there was an issue with gestures n...  issue gesture navigation launch sure fix I wou...
# 404       404              2                99.18  phone, fix, samson, use, get, would, go, goose...  > They chose that instead of battery, people a...  choose instead battery people perfectly free c...
# 98         98              2                99.18  phone, fix, samson, use, get, would, go, goose...  Honor is heavily promoting its X9C phone here ...  honor heavily promote c phone malasha break ma...
# 302       302              2                99.18  phone, fix, samson, use, get, would, go, goose...  I have a pixel 9 pro xl. Great phone, no issue...  I fix pro great phone issue whatsoever I need ...
# 90         90              2                99.18  phone, fix, samson, use, get, would, go, goose...  Yeah, as a new owner of my first pixel this fo...  yeah new owner first fix force upon I apple st...
# 357       357              2                99.18  phone, fix, samson, use, get, would, go, goose...  Lol man it's not, I mostly love my s24+ but my...  man I mostly love wife phone pro still smoke p...
# 56         56              2                99.18  phone, fix, samson, use, get, would, go, goose...  Afaik, my Pixel 8 is not much weaker than a Pi...  fix much weak fix I get shutter stroll speck f...
# 338       338              1                99.16  samson, fix, well, get, phone, like, one, appl...  Apple has full control over iOS and pre-instal...  apple full control reinstate third party softw...
# 130       130              1                99.16  samson, fix, well, get, phone, like, one, appl...  I’m experiencing Stockholm Syndrome from my ti...  experience stockholm syndrome time fix everyon...
# 411       411              1                99.16  samson, fix, well, get, phone, like, one, appl...  User: Pixels take more usable pictures than Sa...  user pipe take unable picture samsung samson o...
# 387       387              1                99.16  samson, fix, well, get, phone, like, one, appl...  they are inconsistent ugly grey LCD panel like...  inconsistent ugly grey lead panel like interfa...
# 373       373              3                99.16  fix, well, samson, use, get, phone, like, perf...  "Opinion is wrong"\n\nSo it's their *opinion*?...  opinion wrong opinion either bag opinion see r...
# 40         40              1                99.16  samson, fix, well, get, phone, like, one, appl...  Spend half as much and get 13R and get 90% of ...  spend half much get r get experience much well...
# 423       423              3                99.16  fix, well, samson, use, get, phone, like, perf...  Swipe up as you would otherwise open the app d...  wipe would otherwise open drawer override orig...
# 324       324              3                99.16  fix, well, samson, use, get, phone, like, perf...  It's always a major selling point when the con...  always major sell point consumer personality t...
# 253       253              3                99.16  fix, well, samson, use, get, phone, like, perf...  One of the most inaccurate things parroted on ...  one inaccurate thing part sub I use nova niaga...
# 68         68              2                99.11  phone, fix, samson, use, get, would, go, goose...  This is correct. Pixel IS a good phone, but it...  correct fix good phone flagship phone even use...
# 79         79              2                99.11  phone, fix, samson, use, get, would, go, goose...  - OneUI and ugly Squircles embedded everywhere...  one ugly squire embed everywhere camera oversa...
# 167       167              2                99.11  phone, fix, samson, use, get, would, go, goose...  > As for silicone carbon batteries, they are j...  silicone carbon battery become norm flagship p...
# 54         54              3                99.10  fix, well, samson, use, get, phone, like, perf...  They say it's better every year, and that it's...  say well every year thank new chip old powerfu...
# 272       272              1                99.10  samson, fix, well, get, phone, like, one, appl...  Just keep the better out of the two for exampl...  keep well two example samson internet way op c...
# 374       374              1                99.10  samson, fix, well, get, phone, like, one, appl...  You have to go into your android settings and ...  go andros setting set default launch lawnchair...
# 203       203              1                99.10  samson, fix, well, get, phone, like, one, appl...  The 13R is not the Indian variant. It's the bu...  r indian variant budget worldwide version bad ...
# 151       151              1                99.10  samson, fix, well, get, phone, like, one, appl...  True Samsung really shat the bed this year and...  true samson really bed year I hope sell unit r...
# 4           4              1                99.10  samson, fix, well, get, phone, like, one, appl...  Tensor chip, no UFS 4.0 but of course if it's ...  tenor chip course goose issue fix flagship pho...
# 421       421              3                99.10  fix, well, samson, use, get, phone, like, perf...  Here is a video of me on pixel 9 pro xl attemp...  video I fix pro attempt wipe bring nova home s...
# 148       148              3                99.10  fix, well, samson, use, get, phone, like, perf...  Try taking a 4k60HDR video on both and sending...  try take video send friend snapdragon go accom...
# 192       192              1                99.03  samson, fix, well, get, phone, like, one, appl...  Samsung does a great job at this, too. I rarel...  samson great job I rarely ever get spasm call ...
# 125       125              1                99.03  samson, fix, well, get, phone, like, one, appl...  Not weird at all. The S24 line up also beat th...  weird line also beat fix line release january ...
# 327       327              3                99.03  fix, well, samson, use, get, phone, like, perf...  I'm hoping this is fixed, but sometimes on nov...  I hope fix sometimes nova I go home gesture I ...
# 44         44              3                99.03  fix, well, samson, use, get, phone, like, perf...  Yes you can, the S25 camera is the worst\nAny ...  yes camera worst movement flurry since say fix...
# 405       405              1                99.03  samson, fix, well, get, phone, like, one, appl...  Yes, it's absolutely true for all system apps....  yes absolutely true system difference whether ...
# 244       244              2                99.02  phone, fix, samson, use, get, would, go, goose...  And we STILL have [people ITT who say "just us...  still people say use manualhtpsoldreditcomrand...
# 251       251              2                99.02  phone, fix, samson, use, get, would, go, goose...  This is a very limited perspective, maybe for ...  limit perspective maybe launch major sell poin...
# 355       355              2                99.02  phone, fix, samson, use, get, would, go, goose...  Eeeehhhh they kind of are.\n\nI guess if we wa...  eh kind I guess want technical downgrade room ...
# 303       303              2                99.02  phone, fix, samson, use, get, would, go, goose...  I would not confidently say flawless. There ar...  I would confidently say lawless still mode iss...
# 0           0              2                99.02  phone, fix, samson, use, get, would, go, goose...  Jeez this thread really opened up the fanboy w...  je thread really open fancy war I feel like fi...
# 37         37              2                99.02  phone, fix, samson, use, get, would, go, goose...  the Pixel 9 at least has 4700mAh, the base S25...  fix least may base may I care optimize os may ...
# 158       158              3                98.96  fix, well, samson, use, get, phone, like, perf...  It's really quite laughable. It means you can ...  really quite laughable mean use phone casual m...
# 236       236              1                98.95  samson, fix, well, get, phone, like, one, appl...  Never played the game, but every time people q...  never play game every time people quote games ...
# 263       263              1                98.95  samson, fix, well, get, phone, like, one, appl...  I recently switched to iOS to check what the o...  I recently switch check side nowadays instal r...
# 366       366              1                98.95  samson, fix, well, get, phone, like, one, appl...  Coz even on Samsung hardware if you use other ...  co even samson hardware use software like gram...
# 33         33              1                98.95  samson, fix, well, get, phone, like, one, appl...  Long story short, I don't think I can justify ...  long story short I think I justify fix variant...
# 12         12              2                98.91  phone, fix, samson, use, get, would, go, goose...  Just bought a new phone yesterday! Been using ...  buy new phone yesterday use samson since relea...
# 402       402              2                98.91  phone, fix, samson, use, get, would, go, goose...  It isn't unique to Nova. It happens on multipl...  unique nova happen multiple different launch I...
# 399       399              2                98.91  phone, fix, samson, use, get, would, go, goose...  Yes there is, when closing an app you need to ...  yes closing need wait animation finish stroll ...
# 197       197              2                98.91  phone, fix, samson, use, get, would, go, goose...  With Pixel phones you do not get two of everyt...  fix phone get two everything like samson phone...
# 35         35              2                98.91  phone, fix, samson, use, get, would, go, goose...  Idk if its just me but the 3x on the pixel loo...  ink I x fix look like ass super digitize clear...
# 78         78              2                98.91  phone, fix, samson, use, get, would, go, goose...  I was actually looking forward to upgrade to t...  I actually look forward upgrade ultra ultra I ...
# 281       281              2                98.91  phone, fix, samson, use, get, would, go, goose...  Noone's safe against a spy org with extensive ...  bone safe spy org extensive government involve...
# 361       361              3                98.86  fix, well, samson, use, get, phone, like, perf...  The whole article is about choosing the two ph...  whole article choose two phone whole point pow...
# 416       416              3                98.86  fix, well, samson, use, get, phone, like, perf...  I've been using Nova for over a decade... What...  I use nova decade break custom launch keep say...
# 184       184              3                98.86  fix, well, samson, use, get, phone, like, perf...  Have you seen One UI 7 on those s25s displayed...  see one I display restore much fast point prob...
# 62         62              1                98.85  samson, fix, well, get, phone, like, one, appl...  Yes, the Pixel 9 Pro is the better option for ...  yes fix pro well option people unless deep sam...
# 318       318              1                98.85  samson, fix, well, get, phone, like, one, appl...  Why can't it be about the hardware? Didn't Sam...  hardware samson already show feature well stag...
# 228       228              1                98.85  samson, fix, well, get, phone, like, one, appl...  Tbf, Samsung builds the Google Tensors. Qualco...  samson build goose tendon qualcom mediate sams...
# 161       161              1                98.85  samson, fix, well, get, phone, like, one, appl...  The Cameras themselves aren't bad. It's their ...  camera bad default shutter speed slow compare ...
# 91         91              1                98.85  samson, fix, well, get, phone, like, one, appl...  The customization with goodlock is amazing, I ...  customization wedlock amazing I sure goose sca...
# 386       386              1                98.85  samson, fix, well, get, phone, like, one, appl...  That's your opinion mate. Even as I am typing ...  opinion mate even I tie fix I use samson reall...
# 94         94              1                98.85  samson, fix, well, get, phone, like, one, appl...  Samsung always was ahead with TouchWiz, but it...  samson always ahead touchwiz feel bloat one am...
# 347       347              1                98.85  samson, fix, well, get, phone, like, one, appl...  and Samsung gets a free pass for agreeing to i...  samson get free pass agree include cheap box e...
# 169       169              2                98.78  phone, fix, samson, use, get, would, go, goose...  On the other hand, they offered like 200$ for ...    hand offer like mean I would pay barely upgrade
# 368       368              2                98.78  phone, fix, samson, use, get, would, go, goose...  I would bet money that less than 50% of Androi...     I would bet money less andros user know launch
# 116       116              2                98.78  phone, fix, samson, use, get, would, go, goose...  S25 is smaller and lighter than Pixel 9.\n\nS2...  small lighter fix pretty much small phone stil...
# 362       362              2                98.78  phone, fix, samson, use, get, would, go, goose...  There's no use speaking to you or this hivemin...  use speak hivemind group see beyond processor ...
# 191       191              2                98.78  phone, fix, samson, use, get, would, go, goose...  You only get the max if you have last year's p...      get max last year phone discount go far ultra
# 259       259              2                98.78  phone, fix, samson, use, get, would, go, goose...  >or square or those childish shape Samsung use...  square childish shape samson use I even know n...
# 391       391              3                98.75  fix, well, samson, use, get, phone, like, perf...  It's possible to get decent pictures with a st...  possible get decent picture steady hand lot te...
# 390       390              3                98.75  fix, well, samson, use, get, phone, like, perf...  buy google phone to degoogle it for privacy an...  buy goose phone degogle privacy still manage s...
# 392       392              3                98.75  fix, well, samson, use, get, phone, like, perf...  For the years I carried a z fold I always brou...  year I carry z fold I always bring fix I camer...
# 340       340              3                98.75  fix, well, samson, use, get, phone, like, perf...  Europe is on such a different reality lol. No ...  europe different reality one use message whats...
# 286       286              3                98.75  fix, well, samson, use, get, phone, like, perf...  The fact those photos are in bright daylight c...  fact photo bright daylight condition mean much...
# 45         45              3                98.75  fix, well, samson, use, get, phone, like, perf...  You can go wrong, the base S25 has horrendous ...  go wrong base horrendous battery life I user y...
# 352       352              3                98.75  fix, well, samson, use, get, phone, like, perf...  They've been cracked also.  Only iOS and graph...  crack also graphene remain defeat tell lot rea...
# 72         72              1                98.74  samson, fix, well, get, phone, like, one, appl...  > You can't charge flagship price for subpar h...  charge flagship price supper hardware samson t...
# 291       291              1                98.74  samson, fix, well, get, phone, like, one, appl...  > on par in CPU performance with a Snapdragon ...  par cup performance snapdragon gen like gen fa...
# 254       254              1                98.74  samson, fix, well, get, phone, like, one, appl...  I switch between Lawnchair and Niagara; haven'...  I switch lawnchair niagara come across bag als...
# 179       179              1                98.74  samson, fix, well, get, phone, like, one, appl...  It's not just the insanely good GoodLock custo...  insanely good wedlock customization also aplel...
# 59         59              3                98.61  fix, well, samson, use, get, phone, like, perf...  It's not only about strong performance but als...  strong performance also futureprofe fix become...
# 341       341              2                98.61  phone, fix, samson, use, get, would, go, goose...  Can you show me a phone with 5000 mAh battery ...  show I phone may battery weigh grass mm thick ...
# 9           9              2                98.61  phone, fix, samson, use, get, would, go, goose...  You can go wrong if you prefer not having a pe...  go wrong prefer permanent goose search bar hom...
# 190       190              2                98.61  phone, fix, samson, use, get, would, go, goose...  Yeah but how much of that is felt IRL. Slabs a...       yeah much feel girl slab bore fold expensive
# 412       412              2                98.61  phone, fix, samson, use, get, would, go, goose...  I'd definitely agree with that number, but I w...   I would definitely agree number I would make bet
# 107       107              2                98.61  phone, fix, samson, use, get, would, go, goose...  Quiet common as Samsung phone launches have al...  quiet common samson phone launch always happen...
# 278       278              2                98.61  phone, fix, samson, use, get, would, go, goose...  Who could possibly have expected people to be ...  could possibly expect people discuss intricacy...
# 401       401              2                98.61  phone, fix, samson, use, get, would, go, goose...  I understand that it's not a big issue for som...  I understand big issue people I sure I get dow...
# 199       199              2                98.61  phone, fix, samson, use, get, would, go, goose...  https://imgur.com/s2BFoRs\n\n6:25 SoT and 48% ...  htpsimgurcomsbfor sot battery leave realm pro ...
# ...
# 16         16              3                96.00  fix, well, samson, use, get, phone, like, perf...  They made the same comparison to the s24 with ...                                make comparison fix
# 417       417              3                96.00  fix, well, samson, use, get, phone, like, perf...                           S21fe still gets updates                                   still get update
# 80         80              1                95.96  samson, fix, well, get, phone, like, one, appl...                      S-pen is not wireless anymore                               see tireless anymore
# 205       205              1                95.96  samson, fix, well, get, phone, like, one, appl...                       Nope. I've checked in-store.                               hope I check restore
# 232       232              1                95.96  samson, fix, well, get, phone, like, one, appl...  thumb wise door flag pot joke tidy ghost tooth...  thumb wise door flag pot joke tidy ghost tooth...
# 182       182              1                95.96  samson, fix, well, get, phone, like, one, appl...                   But Samsung camera is so bad....                                  samson camera bad
# 38         38              1                95.96  samson, fix, well, get, phone, like, one, appl...                      Oppo find x8 better than both                                     oo find x well
# 337       337              1                95.96  samson, fix, well, get, phone, like, one, appl...  Well if you get me an S25 I'll try it out for ...                                   well get I I try
# 103       103              1                95.96  samson, fix, well, get, phone, like, one, appl...         s25 snapdragon is better than s24 exynos..                              snapdragon well exyno
# 334       334              1                95.96  samson, fix, well, get, phone, like, one, appl...     There's a bug for my where my launcher freezes                                  bug launch freeze
# 70         70              2                95.41  phone, fix, samson, use, get, would, go, goose...                             Samsung: Hold my beer!                                   samson hold beer
# 226       226              2                95.41  phone, fix, samson, use, get, would, go, goose...                         You can tell by downvotes.                                      tell downvote
# 261       261              2                95.41  phone, fix, samson, use, get, would, go, goose...  It’s only a minority here that keeps reignitin...                 minority keep reign ancient advice
# 310       310              2                95.41  phone, fix, samson, use, get, would, go, goose...     "To flex on all the non-snapdragon nerds, duh"                        flex nonsnapdragon need due
# 235       235              2                95.41  phone, fix, samson, use, get, would, go, goose...                          Why would anyone do that?                                       would anyone
# 97         97              2                95.41  phone, fix, samson, use, get, would, go, goose...              Which do you prefer: Pixel 9, or S25?                                         prefer fix
# 198       198              2                95.41  phone, fix, samson, use, get, would, go, goose...                      I got my S25 for $333USD lmao                                          I get may
# 210       210              2                95.41  phone, fix, samson, use, get, would, go, goose...  S25 apparently fixed the shutter lag\n\nhttps:...  apparently fix shutter law htpsxcomfahim_al_ma...
# 115       115              3                94.16  fix, well, samson, use, get, phone, like, perf...                     well they both lasts 5hrs-6hrs                                   well last hrshrs
# 122       122              3                94.16  fix, well, samson, use, get, phone, like, perf...                              I heard s25 fixed it.                                         I hear fix
# 255       255              3                94.16  fix, well, samson, use, get, phone, like, perf...                          Huh? How is faster buggy?                                     hut fast buggy
# 328       328              3                94.16  fix, well, samson, use, get, phone, like, perf...                       Do you use it with gestures?                                        use gesture
# 365       365              3                94.16  fix, well, samson, use, get, phone, like, perf...     Both of those statements suck as they are true                                statement suck true
# 64         64              1                94.11  samson, fix, well, get, phone, like, one, appl...                             And the Qualcomm modem                                       qualcom mode
# 370       370              1                94.11  samson, fix, well, get, phone, like, one, appl...                                  Yes, exclusively.                                    yes exclusively
# 142       142              1                94.11  samson, fix, well, get, phone, like, one, appl...           They're probably talking about emulation                            probably talk emulation
# 10         10              1                94.11  samson, fix, well, get, phone, like, one, appl...                                 One UI is superior                                     one I superior
# 342       342              1                94.11  samson, fix, well, get, phone, like, one, appl...       Because it has a Snapdragon. S24 has Exynos.                                   snapdragon exyno
# 420       420              1                94.11  samson, fix, well, get, phone, like, one, appl...                I wish I knew how to do any of this                                      I wish I know
# 216       216              2                91.51  phone, fix, samson, use, get, would, go, goose...                                      It is a phone                                              phone
# 276       276              2                91.51  phone, fix, samson, use, get, would, go, goose...                             What did you trade in?                                              trade
# 77         77              3                89.20  fix, well, samson, use, get, phone, like, perf...                                          [deleted]                                             delete
# 83         83              3                89.20  fix, well, samson, use, get, phone, like, perf...                                          [deleted]                                             delete
# 299       299              3                89.20  fix, well, samson, use, get, phone, like, perf...                                          [deleted]                                             delete
# 268       268              3                89.20  fix, well, samson, use, get, phone, like, perf...                          Why is 23 better than 24?                                               well
# 147       147              3                89.20  fix, well, samson, use, get, phone, like, perf...                                          [deleted]                                             delete
# 307       307              3                89.20  fix, well, samson, use, get, phone, like, perf...                                          [deleted]                                             delete
# 214       214              3                89.20  fix, well, samson, use, get, phone, like, perf...                                          [deleted]                                             delete
# 87         87              3                89.20  fix, well, samson, use, get, phone, like, perf...                                          [deleted]                                             delete
# 170       170              3                89.20  fix, well, samson, use, get, phone, like, perf...                                          [deleted]                                             delete
# 120       120              3                89.20  fix, well, samson, use, get, phone, like, perf...                                          [deleted]                                             delete
# 247       247              1                89.11  samson, fix, well, get, phone, like, one, appl...                                          [removed]                                             remove
# 237       237              1                89.11  samson, fix, well, get, phone, like, one, appl...                 how do you feel about oneplus/oppo                                    feel oneplusopo
# 114       114              1                89.11  samson, fix, well, get, phone, like, one, appl...                                                YEZ                                                yes
# 2           2              1                89.11  samson, fix, well, get, phone, like, one, appl...                                          [removed]                                             remove
# 320       320              1                89.11  samson, fix, well, get, phone, like, one, appl...                                          [removed]                                             remove
# 196       196              1                89.11  samson, fix, well, get, phone, like, one, appl...                                          [removed]                                             remove
# 298       298              1                89.11  samson, fix, well, get, phone, like, one, appl...                   This is blown out of proportion.                                    blow proportion
# 189       189              1                89.11  samson, fix, well, get, phone, like, one, appl...              S25 and S23 are both better than S24.                                               well
# 375       375              3                84.83  fix, well, samson, use, get, phone, like, perf...  If that's happening in Nova launcher that's be...  happen nova launch buy branch analysis chuck o...
# 234       234              2                80.41  phone, fix, samson, use, get, would, go, goose...  Well this is a modern format and uploading it ...  well modern format unload video site would tra...
# 129       129              2                79.97  phone, fix, samson, use, get, would, go, goose...  Funnily enough, I too have an S23 Ultra after ...  funny enough I ultra fix even though ultra com...
# 95         95              1                76.56  samson, fix, well, get, phone, like, one, appl...  By far the best Android skin these days. I'm a...  far well andros skin day I also huge fan mater...
# 177       177              2                72.83  phone, fix, samson, use, get, would, go, goose...  Samsung does a better Job than Google with Qui...  samson well job goose quickshare smart network...
# 231       231              1                71.74  samson, fix, well, get, phone, like, one, appl...  You were meant to say Exynos 5300 modem which ...  mean say exyno mode kill tenor g g exyno mode ...
# 204       204              3                71.32  fix, well, samson, use, get, phone, like, perf...  False. All pixels unless they are running grap...  false pipe unless run graphene os vulnerable c...
# 229       229              2                66.05  phone, fix, samson, use, get, would, go, goose...  It's definitely a weak spot but it's ironicall...  definitely weak spot ironically use samson int...
# 221       221              2                63.30  phone, fix, samson, use, get, would, go, goose...  I mean it's true that it's like a three genera...  I mean true like three generation difference q...
# 207       207              2                61.20  phone, fix, samson, use, get, would, go, goose...  And then there are companies like Honor unfort...  company like honor unfortunately naively avail...
# 67         67              2                60.41  phone, fix, samson, use, get, would, go, goose...  That's the thing, before they would offer this...  thing would offer sub par hardware reasonable ...
# 138       138              2                58.56  phone, fix, samson, use, get, would, go, goose...  yeah there's literally nothing that makes pixe...  yeah literally nothing make fix phone stand pr...
# 135       135              3                56.81  fix, well, samson, use, get, phone, like, perf...  My issue is the price and borderline lies Goog...  issue price border lie goose put regard tenor ...
# 218       218              2                55.89  phone, fix, samson, use, get, would, go, goose...  This is how I feel too.\n\nThe new Tensor chip...  I feel new tenor chip fine fix pro go model ul...
# 75         75              1                55.62  samson, fix, well, get, phone, like, one, appl...  If people are WILLING to buy a phone with 128G...  people willing buy phone go storage teach over...
# 124       124              2                54.50  phone, fix, samson, use, get, would, go, goose...  How do u know about the s25 battery life even ...  u know battery life even ship customer u assum...
# 66         66              1                53.93  samson, fix, well, get, phone, like, one, appl...  and? if you aren't gaming on a cell phone that...  gaze cell phone make much difference vs play i...
# 32         32              3                53.04  fix, well, samson, use, get, phone, like, perf...  You can easily go wrong if you get a pixel ove...     easily go wrong get fix samson even speck lack
# 132       132              2                52.52  phone, fix, samson, use, get, would, go, goose...  It most definitely is a phone. Out of the line...    definitely phone line phone one still might get
# 81         81              2                51.94  phone, fix, samson, use, get, would, go, goose...  The S25 Ultra has a new ultra wide camera, 50M...  ultra new ultra wide camera instead additional...
# 330       330              3                51.64  fix, well, samson, use, get, phone, like, perf...  "opinion is wrong because I didn't experience ...  opinion wrong I experience anything pull right...
# 415       415              2                51.03  phone, fix, samson, use, get, would, go, goose...  I use a third party launcher on pixels and I f...  I use third party launch pipe I find problem p...
# 51         51              2                50.78  phone, fix, samson, use, get, would, go, goose...  I was a Pixel LOVER for many, many years. Then...  I fix lover many many year I buy galaxy ultra ...
# 82         82              1                50.48  samson, fix, well, get, phone, like, one, appl...  And pixel still don't have vapour chamber in t...  fix still vapour chamber normal heat like I ma...
# 349       349              2                49.66  phone, fix, samson, use, get, would, go, goose...       Pixel historically never had deals as insane                 fix historically never deal insane
# 25         25              2                43.74  phone, fix, samson, use, get, would, go, goose...                           Aren't both...expensive?                                      bothexpensive
# 48         48              2                43.74  phone, fix, samson, use, get, would, go, goose...                      Mkmm,L0l8al⁰⁸9à AA Aàraaa9coq                                     mkmlala aracoq
# 113       113              2                43.74  phone, fix, samson, use, get, would, go, goose...                             Aren’t they both $800?                                              agent
# 317       317              2                43.74  phone, fix, samson, use, get, would, go, goose...                               Hahaha autocorrect 🙄                                  havana autocorect
